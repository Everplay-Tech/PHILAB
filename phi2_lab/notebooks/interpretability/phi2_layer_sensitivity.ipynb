# %% [markdown]
# # Phi-2 Layer Sensitivity Notebook
# This lab notebook logs manual ablation notes for Phi-2.

# %% [markdown]
# ## Attention head sweeps
# - Heads 0-7: lexical cleanup; ablations increase repetition.
# - Heads 8-15: math/operator tracking; sensitive to symbol swaps.
# - Heads 16-23: code layout guardians; degrade indentation when zeroed.
# - Heads 24-31: reasoning routers; zeroing causes chain-of-thought collapse.

# %% [markdown]
# ## MLP block probes
# - Layers 0-7 respond to punctuation, shaping lexical spacing.
# - Layers 8-23 encode entities/relations; logistic probes show class-separable vectors.
# - Layers 24-31 boost reasoning heuristics; final block saturates for planning prompts.
